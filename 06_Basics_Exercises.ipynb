# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Exercise 1:<p>
# Write a Python program to implement a Carbon Calculator.<br>
# [https://www.hkelectric.com/en/customer-services/carbon-calculator ](https://www.hkelectric.com/en/customer-services/carbon-calculator)
# - Only implement "By annual electricity consumption"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Exercise 2:<p>
# A local bank hires you to design and develop a business application that can convert HKD to RMB.
